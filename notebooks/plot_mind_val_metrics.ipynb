# %% [markdown]
# ### This notebook contains bar plots visualizing the metrics from `..outputs/mind-val-metrics.csv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

mind_val_metrics = pd.read_csv('../outputs/mind-val-metrics.csv')
print(mind_val_metrics.head())
# Out:
#   recommender    NDCG@5   NDCG@10       MRR     RBO@5    RBO@10
# 0         mmr  0.359997  0.504865  0.312768  0.227220  0.323336
# 1        nrms  0.451955  0.547167  0.371511  0.391269  0.607834
# 2        pfar  0.453286  0.549196  0.371573  0.391268  0.607833
# 3     softmax  0.418232  0.517259  0.333344  0.210365  0.373080
# 4  topic-cali  0.453250  0.549123  0.371573  0.391268  0.607833

# %%
plt.figure(figsize=(5, 5))
plt.bar(mind_val_metrics['recommender'], mind_val_metrics['NDCG@5'], color='blue')
plt.title('NDCG@5 by recommender')
plt.ylabel('Value')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 5))
plt.bar(mind_val_metrics['recommender'], mind_val_metrics['NDCG@10'], color='blue')
plt.title('NDCG@10 by recommender')
plt.ylabel('Value')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 5))
plt.bar(mind_val_metrics['recommender'], mind_val_metrics['MRR'], color='blue')
plt.title('MRR by recommender')
plt.ylabel('Value')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 5))
plt.bar(mind_val_metrics['recommender'], mind_val_metrics['RBO@5'], color='blue')
plt.title('RBO@5 by recommender')
plt.ylabel('Value')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 5))
plt.bar(mind_val_metrics['recommender'], mind_val_metrics['RBO@10'], color='blue')
plt.title('RBO@10 by recommender')
plt.xlabel('recommender')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
